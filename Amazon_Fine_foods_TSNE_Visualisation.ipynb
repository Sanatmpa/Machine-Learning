# %% [markdown]
# # Amazon Fine Foods review: TSNE Exercise

# %%
#Import section
import numpy as np
import pandas as pd
import sqlite3
import string
import nltk

# %%
c=sqlite3.connect('G:\ML\Data_Sets\Amazon\database.sqlite')

# %%
filtered_data=pd.read_sql_query(""" select * from reviews where score!=3 """,c)

# %%
#Converting scores to Positive or negative

def partition(x):
    if x<3:
        return 'negative'
    else:
        return 'positive'
    
tmp=filtered_data['Score']
new=tmp.map(partition)
new.head()
filtered_data['Score']=new

# %%
filtered_data.shape
# Out:
# (525814, 10)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Data Deduplication

# %%
d=pd.read_sql_query(""" 
select * 
from reviews
where score!=3 and UserId= 'AR5J8UI46CURR'
""",c)
d.head()
# Out:
#        Id   ProductId         UserId      ProfileName  HelpfulnessNumerator  \
# 0   73791  B000HDOPZG  AR5J8UI46CURR  Geetha Krishnan                     2
# 1   78445  B000HDL1RQ  AR5J8UI46CURR  Geetha Krishnan                     2
# 2  138277  B000HDOPYM  AR5J8UI46CURR  Geetha Krishnan                     2
# 3  138317  B000HDOPYC  AR5J8UI46CURR  Geetha Krishnan                     2
# 4  155049  B000PAQ75C  AR5J8UI46CURR  Geetha Krishnan                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       2      5  1199577600
# 1                       2      5  1199577600
# 2                       2      5  1199577600
# 3                       2      5  1199577600
# 4                       2      5  1199577600
#
#                              Summary  \
# 0  LOACKER QUADRATINI VANILLA WAFERS
# 1  LOACKER QUADRATINI VANILLA WAFERS
# 2  LOACKER QUADRATINI VANILLA WAFERS
# 3  LOACKER QUADRATINI VANILLA WAFERS
# 4  LOACKER QUADRATINI VANILLA WAFERS
#
#                                                 Text
# 0  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 1  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 2  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 3  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 4  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...

# %%
sorted_data=filtered_data.sort_values('ProductId',ascending= True,axis=0,na_position='last',inplace=False)

# %%
dedup_data=sorted_data.drop_duplicates(subset={"UserId",'ProfileName','Time','Text'},keep='first', inplace= False)
fin_data=dedup_data
dedup_data.shape
# Out:
# (364173, 10)

# %%
dedup_data=dedup_data[dedup_data.HelpfulnessNumerator <= dedup_data.HelpfulnessDenominator]
dedup_data.shape
# Out:
# (364171, 10)

# %%
conn=sqlite3.connect('G:\ML\Data_Sets\Amazon\clean_data.sqlite')
c=conn.cursor()
conn.text_factory=str
dedup_data.to_sql('Reviews',if_exists='replace',index=True, index_label=None, chunksize=None, dtype=None)

# %% [markdown]
# # Text preprocessing

# %%
#Funcns for clean HTML & Punc

import re

def cleanHtml(s):
    clean=re.compile('<.*?>')
    cleared= re.sub(clean,' ',s)
    return cleared

def cleanPunc(s):
    cleared=re.sub('[?|!|\'|"|(|)|.|#|]',r' ',s)
    return cleared

# %%
#Stem 

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))
sno=nltk.stem.SnowballStemmer('english')

print(sno.stem('Tasty'))
# Out:
# tasti

# %%
#Program to clean the words

import time
i=0 #Review counter
str=''
filtered_text=[]
pos_words=[]
neg_words=[]
start=time.time()
print('Operation started at : {} '.format(start))
for sentence in dedup_data['Text'].values:
    filtered_sentence=[]
    clean=cleanHtml(sentence)
    clean=cleanPunc(clean)
    for words in clean.split():
        #print(type(words))
        if(len(words)>2 and words.isalpha()):
            stem=(sno.stem(words.lower()))
            filtered_sentence.append(stem)
            if (dedup_data['Score'].values)[i]=='positive':
                pos_words.append(stem)
            if (dedup_data['Score'].values)[i]=='negative':
                neg_words.append(stem)
            
        else:
            continue
            
    str1=' '.join(filtered_sentence)
    filtered_text.append(str1)
    i+=1
    #print('{} reviews completed'.format(i))

dedup_data['New']=filtered_text
end=time.time()-start
print('Time taken = {} '.format(end))
# Out:
# Operation started at : 1535894028.5856168
# Time taken = 1941.750880241394
# C:\Users\Sanat\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dedup_data.head(5)
# Out:
#             Id   ProductId          UserId                  ProfileName  \
# 138706  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 138688  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 138689  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 138690  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 138691  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#         HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 138706                     0                       0  positive   939340800
# 138688                     1                       1  positive  1194739200
# 138689                     1                       1  positive  1191456000
# 138690                     1                       1  positive  1076025600
# 138691                     3                       4  positive  1018396800
#
#                                            Summary  \
# 138706                   EVERY book is educational
# 138688  Love the book, miss the hard cover version
# 138689               chicken soup with rice months
# 138690      a good swingy rhythm for reading aloud
# 138691             A great way to learn the months
#
#                                                      Text  \
# 138706  this witty little book makes my son laugh at l...
# 138688  I grew up reading these Sendak books, and watc...
# 138689  This is a fun way for children to learn their ...
# 138690  This is a great little book to read aloud- it ...
# 138691  This is a book of poetry about the months of t...
#
#                                                       New
# 138706  this witti littl book make son laugh loud reci...
# 138688  grew read these sendak and watch the realli ro...
# 138689  this fun way for children learn their month th...
# 138690  this great littl book read has nice rhythm wel...
# 138691  this book poetri about the month the year goe ...

# %%
#Exporting to SQL Lite

conn=sqlite3.connect('G:\ML\Data_Sets\Amazon\Final1_DB.sqlite')
conn.text_factory=str
dedup_data.to_sql('Reviews',conn, schema=None, if_exists='replace', index=True, index_label=None, chunksize=None, dtype=None)

# %% [markdown]
# # Creating Subset of data with 3k points from each class:

# %%
g=dedup_data.groupby('Score')
a=g.get_group('positive').sample(3000)
a.head(3)
# Out:
#             Id   ProductId          UserId      ProfileName  \
# 299069  323958  B005JRMUIY  A3TUSOAWOO2G0Q          K. Beal
# 42234    45956  B0012ZQPWY  A3F4079MFPO2EQ          cjer504
# 140165  152112  B000N8N7K4  A3Q7C0V12LS2WF  L. Muir "Kubda"
#
#         HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 299069                     0                       1  positive  1336521600
# 42234                      0                       0  positive  1334275200
# 140165                     1                       1  positive  1317254400
#
#                     Summary  \
# 299069     The Best Flavor!
# 42234   one of the greatest
# 140165            WONDERFUL
#
#                                                      Text  \
# 299069  The Simply Bar is a great on-the-run thing to ...
# 42234   This sauce is awesome. It is on the sweeter si...
# 140165  Good value for this.  I intend to use it all.<...
#
#                                                       New
# 299069  the simpli bar great thing eat has ampl amount...
# 42234   this sauc awesom the sweeter side the but defi...
# 140165  good valu for this intend use all tsp hot wate...

# %%
b=g.get_group('negative').sample(3000)
new_data=a.append(b,ignore_index= True)
new_data.shape
# Out:
# (6000, 11)

# %%
label=new_data['Score']
label.shape
# Out:
# (6000,)

# %% [markdown]
# # tSNE representation of Bag of Words:

# %%
BOW=cv.fit_transform(new_data['New'].values)
print('Shape of BOW :',BOW.get_shape())
print('No of Dim:',BOW.get_shape()[1])
# Out:
# Shape of BOW : (6000, 10280)
# No of Dim: 10280

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler(with_mean=False)
scaled_BOW= scaler.fit_transform(BOW)

# %%
from sklearn.manifold import TSNE
model=TSNE(n_components=2,random_state=0)
t_BOW= model.fit_transform(scaled_BOW.toarray())

# %%
t_BOW.shape
# Out:
# (6000, 2)

# %%
fin_BOW=np.vstack((t_BOW.T,label)).T
BOW_df=pd.DataFrame(fin_BOW,columns=('v1','v2','Labels'))
BOW_df.head()
# Out:
#         v1       v2    Labels
# 0  34.4299  36.1223  positive
# 1 -46.2958 -27.7618  positive
# 2  94.4711  30.7249  positive
# 3   46.405  38.5322  positive
# 4 -3.52466  1.40569  positive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.FacetGrid(BOW_df,hue='Labels',palette=['b','r'],size=8).map(plt.scatter,'v1','v2').add_legend()
plt.title('BOW tSNE')
plt.show()

# %% [markdown]
# # tSNE implementation of tf-IDF :

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

ti=TfidfVectorizer()
ti_data=ti.fit_transform(new_data['New'].values)
ti_data.shape
# Out:
# (6000, 10280)

# %%
# Column Standardisation
std_ti=scaler.fit_transform(ti_data)

# %%
m1=TSNE(n_components=2,random_state=1,verbose=2,perplexity=60)
t_tfidf=m1.fit_transform(std_ti.todense())
# Out:
# [t-SNE] Computing 181 nearest neighbors...
# [t-SNE] Indexed 6000 samples in 18.953s...
# [t-SNE] Computed neighbors for 6000 samples in 1711.391s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6000
# [t-SNE] Computed conditional probabilities for sample 2000 / 6000
# [t-SNE] Computed conditional probabilities for sample 3000 / 6000
# [t-SNE] Computed conditional probabilities for sample 4000 / 6000
# [t-SNE] Computed conditional probabilities for sample 5000 / 6000
# [t-SNE] Computed conditional probabilities for sample 6000 / 6000
# [t-SNE] Mean sigma: 12.516206
# [t-SNE] Computed conditional probabilities in 10.015s
# [t-SNE] Iteration 50: error = 127.9227295, gradient norm = 0.2969297 (50 iterations in 68.846s)
# [t-SNE] Iteration 100: error = 129.0011444, gradient norm = 0.2925230 (50 iterations in 46.923s)
# [t-SNE] Iteration 150: error = 126.6063843, gradient norm = 0.2258634 (50 iterations in 64.832s)
# [t-SNE] Iteration 200: error = 130.2448425, gradient norm = 0.2341719 (50 iterations in 59.555s)
# [t-SNE] Iteration 250: error = 128.0802002, gradient norm = 0.2672456 (50 iterations in 58.496s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 128.080200
# [t-SNE] Iteration 300: error = 4.1912346, gradient norm = 0.0234347 (50 iterations in 42.850s)
# [t-SNE] Iteration 350: error = 3.0444267, gradient norm = 0.0138546 (50 iterations in 51.953s)
# [t-SNE] Iteration 400: error = 2.5853031, gradient norm = 0.0156334 (50 iterations in 53.983s)
# [t-SNE] Iteration 450: error = 2.4733920, gradient norm = 0.0138308 (50 iterations in 53.397s)
# [t-SNE] Iteration 500: error = 2.4501688, gradient norm = 0.0031009 (50 iterations in 55.966s)
# [t-SNE] Iteration 550: error = 2.4400632, gradient norm = 0.0005020 (50 iterations in 65.358s)
# [t-SNE] Iteration 600: error = 2.4331205, gradient norm = 0.0001319 (50 iterations in 65.377s)
# [t-SNE] Iteration 650: error = 2.4283795, gradient norm = 0.0000740 (50 iterations in 65.711s)
# [t-SNE] Iteration 700: error = 2.4245086, gradient norm = 0.0000674 (50 iterations in 67.556s)
# [t-SNE] Iteration 750: error = 2.4214649, gradient norm = 0.0000540 (50 iterations in 67.121s)
# [t-SNE] Iteration 800: error = 2.4189079, gradient norm = 0.0000544 (50 iterations in 66.673s)
# [t-SNE] Iteration 850: error = 2.4169686, gradient norm = 0.0000499 (50 iterations in 69.125s)
# [t-SNE] Iteration 900: error = 2.4153519, gradient norm = 0.0000433 (50 iterations in 67.045s)
# [t-SNE] Iteration 950: error = 2.4137709, gradient norm = 0.0000403 (50 iterations in 64.663s)
# [t-SNE] Iteration 1000: error = 2.4126699, gradient norm = 0.0000427 (50 iterations in 68.077s)
# [t-SNE] Error after 1000 iterations: 2.412670

# %%
print(t_tfidf.shape)
final_tfidf=np.vstack((t_tfidf.T,label)).T
print(final_tfidf.shape)
# Out:
# (6000, 2)
# (6000, 3)

# %%
tfidf_df=pd.DataFrame(final_tfidf,columns=('v1','v2','Labels'))
tfidf_df.head(3)
# Out:
#          v1       v2    Labels
# 0  -16.5005 -16.0195  positive
# 1   8.08726  12.6562  positive
# 2 -0.474776 -1.43325  positive

# %%
sns.FacetGrid(tfidf_df,hue='Labels',palette=['b','r'],size=8).map(plt.scatter,'v1','v2').add_legend()
plt.title('Tf- IDF tSNE')
plt.show()

# %% [markdown]
# # Word2Vec:

# %%
from gensim.models import KeyedVectors
from gensim.models import Word2Vec

# %%
#Training W2V from my corpus

sentence_list=[]
for sent in new_data['New'].values:
    sentence_list.append(sent.split())

# %%
print(new_data['New'][50])
print('*********************************************')
print(sentence_list[50])
# Out:
# like the bob red mill unsweeten coconut the larger flake and work well bake oatmeal the morn like the unsweeten coconut are tri watch our sugar besid coconut sweet who need sugar price was good well
# *********************************************
# ['like', 'the', 'bob', 'red', 'mill', 'unsweeten', 'coconut', 'the', 'larger', 'flake', 'and', 'work', 'well', 'bake', 'oatmeal', 'the', 'morn', 'like', 'the', 'unsweeten', 'coconut', 'are', 'tri', 'watch', 'our', 'sugar', 'besid', 'coconut', 'sweet', 'who', 'need', 'sugar', 'price', 'was', 'good', 'well']

# %%
w2v_mod=Word2Vec(sentence_list,size=50,workers=4)

# %%
type(w2v_mod)
# Out:
# gensim.models.word2vec.Word2Vec

# %%
W2V=list(w2v_mod.wv.vocab)

# %%
print('No of words in W2V {}'.format(len(W2V)))
# Out:
# No of words in W2V 6081

# %% [markdown]
# # Average W2V:

# %%
sent_vect=[]
for sentence in sentence_list:
    s_v=np.zeros(50)
    count=0
    for words in sentence:
        try:
            tmp=w2v_mod.wv[words]
            s_v+=tmp
            count+=1
        except:
            continue
    if count!=0:
        s_v/=count
    sent_vect.append(s_v)
print(sent_vect)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
std_avg = scaler.fit_transform(sent_vect)

# %%
t_avg=m1.fit_transform(std_avg)
# Out:
# [t-SNE] Computing 181 nearest neighbors...
# [t-SNE] Indexed 6000 samples in 0.064s...
# [t-SNE] Computed neighbors for 6000 samples in 15.896s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6000
# [t-SNE] Computed conditional probabilities for sample 2000 / 6000
# [t-SNE] Computed conditional probabilities for sample 3000 / 6000
# [t-SNE] Computed conditional probabilities for sample 4000 / 6000
# [t-SNE] Computed conditional probabilities for sample 5000 / 6000
# [t-SNE] Computed conditional probabilities for sample 6000 / 6000
# [t-SNE] Mean sigma: 1.743141
# [t-SNE] Computed conditional probabilities in 1.886s
# [t-SNE] Iteration 50: error = 81.4868469, gradient norm = 0.0000039 (50 iterations in 50.382s)
# [t-SNE] Iteration 100: error = 81.4761963, gradient norm = 0.0014622 (50 iterations in 57.318s)
# [t-SNE] Iteration 150: error = 80.4921265, gradient norm = 0.0000410 (50 iterations in 58.628s)
# [t-SNE] Iteration 200: error = 80.4884033, gradient norm = 0.0000037 (50 iterations in 47.578s)
# [t-SNE] Iteration 250: error = 80.4884109, gradient norm = 0.0000051 (50 iterations in 47.296s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.488411
# [t-SNE] Iteration 300: error = 2.7394531, gradient norm = 0.0015432 (50 iterations in 51.645s)
# [t-SNE] Iteration 350: error = 2.4982841, gradient norm = 0.0005066 (50 iterations in 56.177s)
# [t-SNE] Iteration 400: error = 2.4044993, gradient norm = 0.0002594 (50 iterations in 57.515s)
# [t-SNE] Iteration 450: error = 2.3547003, gradient norm = 0.0001696 (50 iterations in 56.674s)
# [t-SNE] Iteration 500: error = 2.3245623, gradient norm = 0.0001088 (50 iterations in 55.153s)
# [t-SNE] Iteration 550: error = 2.3053141, gradient norm = 0.0000874 (50 iterations in 60.237s)
# [t-SNE] Iteration 600: error = 2.2923820, gradient norm = 0.0000617 (50 iterations in 54.835s)
# [t-SNE] Iteration 650: error = 2.2830641, gradient norm = 0.0000513 (50 iterations in 55.539s)
# [t-SNE] Iteration 700: error = 2.2761714, gradient norm = 0.0000433 (50 iterations in 54.870s)
# [t-SNE] Iteration 750: error = 2.2712212, gradient norm = 0.0000360 (50 iterations in 54.440s)
# [t-SNE] Iteration 800: error = 2.2673941, gradient norm = 0.0000320 (50 iterations in 55.860s)
# [t-SNE] Iteration 850: error = 2.2644131, gradient norm = 0.0000282 (50 iterations in 54.691s)
# [t-SNE] Iteration 900: error = 2.2621722, gradient norm = 0.0000253 (50 iterations in 55.794s)
# [t-SNE] Iteration 950: error = 2.2602971, gradient norm = 0.0000237 (50 iterations in 55.491s)
# [t-SNE] Iteration 1000: error = 2.2589009, gradient norm = 0.0000217 (50 iterations in 55.390s)
# [t-SNE] Error after 1000 iterations: 2.258901

# %%
t_avg.shape
# Out:
# (6000, 2)

# %%
final_avgw2v=np.vstack((t_avg.T,label)).T
final_avgw2v.shape
tfidf_w2v=pd.DataFrame(final_avgw2v,columns=('v1','v2','Labels'))
tfidf_w2v.head(3)
# Out:
#         v1       v2    Labels
# 0  34.6972  28.1338  positive
# 1 -1.07206  9.93056  positive
# 2  13.5429  46.9492  positive

# %%
sns.FacetGrid(tfidf_w2v,hue='Labels',palette=['b','r'],size=8).map(plt.scatter,'v1','v2').add_legend()
plt.title('AVG W2V tSNE')
plt.show()

# %% [markdown]
# # tSNE representation of TfIdf- Word2Vec

# %%
feats=ti.get_feature_names()

row=0
tf_sv=[]
for sentence in sentence_list:
    s_v=np.zeros(50)
    weight=0
    for word in sentence:
        try:
            vec=w2v_mod.wv[word]
            tf=ti_data[row,feats.index(word)]
            s_v+=(vec*tf)
            weight+=tf
        except:
            continue
    if weight!=0:
        s_v/=weight
    tf_sv.append(s_v)   
    row+=1

# %%
std_tfidf = scaler.fit_transform(tf_sv)

# %%
t_tfidf_w2v=m1.fit_transform(std_tfidf)
# Out:
# [t-SNE] Computing 181 nearest neighbors...
# [t-SNE] Indexed 6000 samples in 0.067s...
# [t-SNE] Computed neighbors for 6000 samples in 15.572s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6000
# [t-SNE] Computed conditional probabilities for sample 2000 / 6000
# [t-SNE] Computed conditional probabilities for sample 3000 / 6000
# [t-SNE] Computed conditional probabilities for sample 4000 / 6000
# [t-SNE] Computed conditional probabilities for sample 5000 / 6000
# [t-SNE] Computed conditional probabilities for sample 6000 / 6000
# [t-SNE] Mean sigma: 1.691331
# [t-SNE] Computed conditional probabilities in 1.881s
# [t-SNE] Iteration 50: error = 82.0736923, gradient norm = 0.0001541 (50 iterations in 54.297s)
# [t-SNE] Iteration 100: error = 80.2989273, gradient norm = 0.0001286 (50 iterations in 55.020s)
# [t-SNE] Iteration 150: error = 80.2856369, gradient norm = 0.0000149 (50 iterations in 49.062s)
# [t-SNE] Iteration 200: error = 80.2837982, gradient norm = 0.0000127 (50 iterations in 49.474s)
# [t-SNE] Iteration 250: error = 80.2825165, gradient norm = 0.0000115 (50 iterations in 43.407s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.282516
# [t-SNE] Iteration 300: error = 2.4653537, gradient norm = 0.0010318 (50 iterations in 50.078s)
# [t-SNE] Iteration 350: error = 2.2451351, gradient norm = 0.0004081 (50 iterations in 31.697s)
# [t-SNE] Iteration 400: error = 2.1587048, gradient norm = 0.0002097 (50 iterations in 36.018s)
# [t-SNE] Iteration 450: error = 2.1120191, gradient norm = 0.0001373 (50 iterations in 28.902s)
# [t-SNE] Iteration 500: error = 2.0837481, gradient norm = 0.0001044 (50 iterations in 33.907s)
# [t-SNE] Iteration 550: error = 2.0654061, gradient norm = 0.0000750 (50 iterations in 42.781s)
# [t-SNE] Iteration 600: error = 2.0530548, gradient norm = 0.0000571 (50 iterations in 38.811s)
# [t-SNE] Iteration 650: error = 2.0442228, gradient norm = 0.0000463 (50 iterations in 45.991s)
# [t-SNE] Iteration 700: error = 2.0378385, gradient norm = 0.0000401 (50 iterations in 46.385s)
# [t-SNE] Iteration 750: error = 2.0332291, gradient norm = 0.0000367 (50 iterations in 46.881s)
# [t-SNE] Iteration 800: error = 2.0301878, gradient norm = 0.0000338 (50 iterations in 34.031s)
# [t-SNE] Iteration 850: error = 2.0279021, gradient norm = 0.0000308 (50 iterations in 30.444s)
# [t-SNE] Iteration 900: error = 2.0262365, gradient norm = 0.0000275 (50 iterations in 29.204s)
# [t-SNE] Iteration 950: error = 2.0248260, gradient norm = 0.0000251 (50 iterations in 36.440s)
# [t-SNE] Iteration 1000: error = 2.0236020, gradient norm = 0.0000236 (50 iterations in 29.062s)
# [t-SNE] Error after 1000 iterations: 2.023602

# %%
final_tfidfw2v=np.vstack((t_tfidf_w2v.T,label)).T
final_tfidfw2v.shape
# Out:
# (6000, 3)

# %%
final_df=pd.DataFrame(final_tfidfw2v,columns=('v1','v2','Labels'))
final_df.head(3)
# Out:
#         v1       v2    Labels
# 0  41.7628 -1.26614  positive
# 1 -19.0389   7.2239  positive
# 2  22.4964  38.9129  positive

# %%
sns.FacetGrid(final_df,hue='Labels',palette=['b','r'],size=8).map(plt.scatter,'v1','v2').add_legend()
plt.title('Tf-Idf W2V tSNE')
plt.show()
